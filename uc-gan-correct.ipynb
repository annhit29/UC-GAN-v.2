# %%
# !git clone https://github.com/annhit29/UC-GAN-v.2.git
# Out:
# Cloning into 'UC-GAN-v.2'...
# remote: Enumerating objects: 1099, done.
# remote: Counting objects: 100% (1099/1099), done.
# remote: Compressing objects: 100% (712/712), done.
# remote: Total 1099 (delta 437), reused 1028 (delta 370), pack-reused 0
# Receiving objects: 100% (1099/1099), 14.37 MiB | 31.04 MiB/s, done.
# Resolving deltas: 100% (437/437), done.

# %%
# !pip install catboost
# Out:
# Requirement already satisfied: catboost in /opt/conda/lib/python3.10/site-packages (1.2.1)
# Requirement already satisfied: graphviz in /opt/conda/lib/python3.10/site-packages (from catboost) (0.20.1)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from catboost) (3.7.2)
# Requirement already satisfied: numpy>=1.16.0 in /opt/conda/lib/python3.10/site-packages (from catboost) (1.23.5)
# Requirement already satisfied: pandas>=0.24 in /opt/conda/lib/python3.10/site-packages (from catboost) (2.0.2)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from catboost) (1.11.2)
# Requirement already satisfied: plotly in /opt/conda/lib/python3.10/site-packages (from catboost) (5.15.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.24->catboost) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.24->catboost) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->catboost) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->catboost) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->catboost) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->catboost) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->catboost) (9.5.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->catboost) (3.0.9)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from plotly->catboost) (8.2.2)

# %%
# !pip install pyenigma
# Out:
# Collecting pyenigma
#   Downloading pyenigma-0.4.1-py3-none-any.whl (33 kB)
# Installing collected packages: pyenigma
# Successfully installed pyenigma-0.4.1

# %%
# %cd /kaggle/working/
# Out:
# /kaggle/working

# %%
# !python /kaggle/working/UC-GAN-v.2/main.py
# Out:
# Start training...
# Epoch 0 D loss: 85.7396011352539 G_loss: 1.434364676475525
# Enigma to plain :  0.0725
# Enigma M4 to plain :  0.042499999999999996
# TypeX to plain :  0.03777777777777778
# plain to Enigma :  0.07285714285714286
# plain to Enigma M4 :  0.058571428571428566
# plain to Enigma :  0.037142857142857144
# Enigma to Enigma M4 :  0.05625000000000001
# Enigma to TypeX :  0.0675
# Enigma M4 to Enigma :  0.0
# Enigma M4 to TypeX :  0.051250000000000004
# TypeX to Enigma :  0.03888888888888889
# TypeX to Enigma M4 :  0.022222222222222223
# Epoch 10000 D loss: 3.4048428535461426 G_loss: 1.5790014266967773
# Enigma to plain :  0.04699999999999999
# Enigma M4 to plain :  0.04222222222222223
# TypeX to plain :  0.045
# plain to Enigma :  0.06200000000000001
# plain to Enigma M4 :  0.036
# plain to Enigma :  0.032
# Enigma to Enigma M4 :  0.023
# Enigma to TypeX :  0.05600000000000001
# Enigma M4 to Enigma :  0.0
# Enigma M4 to TypeX :  0.05888888888888889
# TypeX to Enigma :  0.03625
# TypeX to Enigma M4 :  0.04625
# Epoch 20000 D loss: 2.7445120811462402 G_loss: 1.77949857711792
# Enigma to plain :  0.052000000000000005
# Enigma M4 to plain :  0.0525
# TypeX to plain :  0.026363636363636367
# plain to Enigma :  0.057499999999999996
# plain to Enigma M4 :  0.056249999999999994
# plain to Enigma :  0.03
# Enigma to Enigma M4 :  0.06
# Enigma to TypeX :  0.062
# Enigma M4 to Enigma :  0.0
# Enigma M4 to TypeX :  0.0475
# TypeX to Enigma :  0.04
# TypeX to Enigma M4 :  0.03272727272727272
# Epoch 30000 D loss: 1.8200817108154297 G_loss: 1.8595527410507202
# Enigma to plain :  0.06900000000000002
# Enigma M4 to plain :  0.048
# TypeX to plain :  0.03666666666666667
# plain to Enigma :  0.065
# plain to Enigma M4 :  0.04833333333333334
# plain to Enigma :  0.036666666666666674
# Enigma to Enigma M4 :  0.05600000000000001
# Enigma to TypeX :  0.05600000000000001
# Enigma M4 to Enigma :  0.0
# Enigma M4 to TypeX :  0.05600000000000001
# TypeX to Enigma :  0.045000000000000005
# TypeX to Enigma M4 :  0.023333333333333334
# Epoch 40000 D loss: 1.7282484769821167 G_loss: 1.7175185680389404
# Enigma to plain :  0.034999999999999996
# Enigma M4 to plain :  0.053333333333333344
# TypeX to plain :  0.06555555555555556
# plain to Enigma :  0.04375
# plain to Enigma M4 :  0.05625
# plain to Enigma :  0.0625
# Enigma to Enigma M4 :  0.04
# Enigma to TypeX :  0.043333333333333335
# Enigma M4 to Enigma :  0.012222222222222221
# Enigma M4 to TypeX :  0.03444444444444445
# TypeX to Enigma :  0.024444444444444442
# TypeX to Enigma M4 :  0.06666666666666667
# Epoch 50000 D loss: 1.9576925039291382 G_loss: 1.90872061252594
# Enigma to plain :  0.020833333333333332
# Enigma M4 to plain :  0.017
# TypeX to plain :  0.006666666666666667
# plain to Enigma :  0.015
# plain to Enigma M4 :  0.01
# plain to Enigma :  0.0175
# Enigma to Enigma M4 :  0.014166666666666668
# Enigma to TypeX :  0.055833333333333346
# Enigma M4 to Enigma :  0.31900000000000006
# Enigma M4 to TypeX :  0.05600000000000001
# TypeX to Enigma :  0.045000000000000005
# TypeX to Enigma M4 :  0.05000000000000001
# Epoch 60000 D loss: 1.82521653175354 G_loss: 1.712255835533142
# Enigma to plain :  0.01727272727272727
# Enigma M4 to plain :  0.006666666666666667
# TypeX to plain :  0.018333333333333333
# plain to Enigma :  0.012222222222222223
# plain to Enigma M4 :  0.005555555555555556
# plain to Enigma :  0.022222222222222223
# Enigma to Enigma M4 :  0.014545454545454545
# Enigma to TypeX :  0.04636363636363638
# Enigma M4 to Enigma :  0.3499999999999999
# Enigma M4 to TypeX :  0.04833333333333334
# TypeX to Enigma :  0.04666666666666666
# TypeX to Enigma M4 :  0.049999999999999996
# Epoch 70000 D loss: 1.7585251331329346 G_loss: 1.697493076324463
# Enigma to plain :  0.023636363636363636
# Enigma M4 to plain :  0.01
# TypeX to plain :  0.0125
# plain to Enigma :  0.015
# plain to Enigma M4 :  0.005
# plain to Enigma :  0.024999999999999998
# Enigma to Enigma M4 :  0.011818181818181818
# Enigma to TypeX :  0.04454545454545455
# Enigma M4 to Enigma :  0.32857142857142857
# Enigma M4 to TypeX :  0.044285714285714296
# TypeX to Enigma :  0.0475
# TypeX to Enigma M4 :  0.03875
# Epoch 80000 D loss: 1.6671520471572876 G_loss: 1.714542031288147
# Enigma to plain :  0.024285714285714292
# Enigma M4 to plain :  0.015555555555555553
# TypeX to plain :  0.011
# plain to Enigma :  0.01
# plain to Enigma M4 :  0.0033333333333333335
# plain to Enigma :  0.02
# Enigma to Enigma M4 :  0.011428571428571429
# Enigma to TypeX :  0.05857142857142856
# Enigma M4 to Enigma :  0.3422222222222222
# Enigma M4 to TypeX :  0.05444444444444444
# TypeX to Enigma :  0.044000000000000004
# TypeX to Enigma M4 :  0.051000000000000004
# Epoch 90000 D loss: 1.5766161680221558 G_loss: 1.8740630149841309
# Enigma to plain :  0.022222222222222223
# Enigma M4 to plain :  0.00875
# TypeX to plain :  0.012857142857142859
# plain to Enigma :  0.01
# plain to Enigma M4 :  0.01
# plain to Enigma :  0.015
# Enigma to Enigma M4 :  0.014444444444444446
# Enigma to TypeX :  0.043333333333333335
# Enigma M4 to Enigma :  0.36874999999999997
# Enigma M4 to TypeX :  0.051250000000000004
# TypeX to Enigma :  0.05285714285714286
# TypeX to Enigma M4 :  0.04285714285714286
# Epoch 100000 D loss: 1.530430555343628 G_loss: 1.6173779964447021
# Enigma to plain :  0.016666666666666666
# Enigma M4 to plain :  0.012
# TypeX to plain :  0.015
# plain to Enigma :  0.013999999999999999
# plain to Enigma M4 :  0.007000000000000001
# plain to Enigma :  0.020999999999999998
# Enigma to Enigma M4 :  0.013333333333333334
# Enigma to TypeX :  0.043333333333333335
# Enigma M4 to Enigma :  0.335
# Enigma M4 to TypeX :  0.051000000000000004
# TypeX to Enigma :  0.036666666666666674
# TypeX to Enigma M4 :  0.05000000000000001
# Epoch 110000 D loss: 1.630869746208191 G_loss: 2.3142130374908447
# Enigma to plain :  0.014444444444444446
# Enigma M4 to plain :  0.02
# TypeX to plain :  0.024444444444444446
# plain to Enigma :  0.01
# plain to Enigma M4 :  0.013749999999999998
# plain to Enigma :  0.0275
# Enigma to Enigma M4 :  0.02222222222222222
# Enigma to TypeX :  0.043333333333333335
# Enigma M4 to Enigma :  0.3466666666666666
# Enigma M4 to TypeX :  0.049999999999999996
# TypeX to Enigma :  0.05222222222222222
# TypeX to Enigma M4 :  0.043333333333333335
# Epoch 120000 D loss: 1.8440635204315186 G_loss: 1.4245754480361938
# Enigma to plain :  0.01
# Enigma M4 to plain :  0.05000000000000001
# TypeX to plain :  0.044
# plain to Enigma :  0.013076923076923076
# plain to Enigma M4 :  0.02538461538461539
# plain to Enigma :  0.04846153846153845
# Enigma to Enigma M4 :  0.04875
# Enigma to TypeX :  0.02
# Enigma M4 to Enigma :  0.0
# Enigma M4 to TypeX :  0.023333333333333334
# TypeX to Enigma :  0.026000000000000002
# TypeX to Enigma M4 :  0.06000000000000001
# Epoch 130000 D loss: 2.2907657623291016 G_loss: 3.9049551486968994
# Enigma to plain :  0.011
# Enigma M4 to plain :  0.03571428571428571
# TypeX to plain :  0.04
# plain to Enigma :  0.002
# plain to Enigma M4 :  0.042
# plain to Enigma :  0.052000000000000005
# Enigma to Enigma M4 :  0.05600000000000001
# Enigma to TypeX :  0.018
# Enigma M4 to Enigma :  0.0
# Enigma M4 to TypeX :  0.018571428571428572
# TypeX to Enigma :  0.04
# TypeX to Enigma M4 :  0.06
# Epoch 140000 D loss: 2.5557360649108887 G_loss: 1.601818561553955
# Enigma to plain :  0.013333333333333334
# Enigma M4 to plain :  0.03375
# TypeX to plain :  0.042222222222222223
# plain to Enigma :  0.021111111111111112
# plain to Enigma M4 :  0.030000000000000002
# plain to Enigma :  0.04
# Enigma to Enigma M4 :  0.035
# Enigma to TypeX :  0.02666666666666667
# Enigma M4 to Enigma :  0.00375
# Enigma M4 to TypeX :  0.0225
# TypeX to Enigma :  0.04555555555555556
# TypeX to Enigma M4 :  0.06888888888888889
# Epoch 150000 D loss: 2.768012285232544 G_loss: 3.8907997608184814
# Enigma to plain :  0.0075
# Enigma M4 to plain :  0.04
# TypeX to plain :  0.04000000000000001
# plain to Enigma :  0.008333333333333333
# plain to Enigma M4 :  0.03833333333333334
# plain to Enigma :  0.04833333333333333
# Enigma to Enigma M4 :  0.052500000000000005
# Enigma to TypeX :  0.017499999999999998
# Enigma M4 to Enigma :  0.0
# Enigma M4 to TypeX :  0.021111111111111112
# TypeX to Enigma :  0.036923076923076927
# TypeX to Enigma M4 :  0.06692307692307693
# Epoch 160000 D loss: 2.4782638549804688 G_loss: 1.3303951025009155
# Enigma to plain :  0.01
# Enigma M4 to plain :  0.036250000000000004
# TypeX to plain :  0.042222222222222223
# plain to Enigma :  0.01
# plain to Enigma M4 :  0.042
# plain to Enigma :  0.05
# Enigma to Enigma M4 :  0.05800000000000001
# Enigma to TypeX :  0.016999999999999998
# Enigma M4 to Enigma :  0.0
# Enigma M4 to TypeX :  0.022500000000000003
# TypeX to Enigma :  0.03222222222222223
# TypeX to Enigma M4 :  0.060000000000000005
# Epoch 170000 D loss: 2.1646456718444824 G_loss: 2.8051364421844482
# Enigma to plain :  0.006666666666666666
# Enigma M4 to plain :  0.038
# TypeX to plain :  0.04833333333333334
# plain to Enigma :  0.008571428571428572
# plain to Enigma M4 :  0.03142857142857143
# plain to Enigma :  0.05285714285714286
# Enigma to Enigma M4 :  0.04666666666666667
# Enigma to TypeX :  0.01666666666666667
# Enigma M4 to Enigma :  0.0
# Enigma M4 to TypeX :  0.020999999999999998
# TypeX to Enigma :  0.034999999999999996
# TypeX to Enigma M4 :  0.056666666666666664
# Epoch 180000 D loss: 1.6187976598739624 G_loss: 1.462862253189087
# Enigma to plain :  0.005
# Enigma M4 to plain :  0.03571428571428571
# TypeX to plain :  0.046
# plain to Enigma :  0.006999999999999999
# plain to Enigma M4 :  0.027000000000000003
# plain to Enigma :  0.051000000000000004
# Enigma to Enigma M4 :  0.05
# Enigma to TypeX :  0.023
# Enigma M4 to Enigma :  0.0
# Enigma M4 to TypeX :  0.02142857142857143
# TypeX to Enigma :  0.036000000000000004
# TypeX to Enigma M4 :  0.06000000000000001
# Epoch 190000 D loss: 1.6754248142242432 G_loss: 2.7946114540100098
# Enigma to plain :  0.005714285714285714
# Enigma M4 to plain :  0.025555555555555557
# TypeX to plain :  0.05499999999999999
# plain to Enigma :  0.00625
# plain to Enigma M4 :  0.01875
# plain to Enigma :  0.02875
# Enigma to Enigma M4 :  0.041428571428571426
# Enigma to TypeX :  0.04428571428571428
# Enigma M4 to Enigma :  0.12888888888888891
# Enigma M4 to TypeX :  0.027777777777777776
# TypeX to Enigma :  0.04750000000000001
# TypeX to Enigma M4 :  0.047499999999999994
# Epoch 200000 D loss: 1.6168292760849 G_loss: 1.6863051652908325
# Enigma to plain :  0.014444444444444446
# Enigma M4 to plain :  0.018571428571428572
# TypeX to plain :  0.04142857142857143
# plain to Enigma :  0.015555555555555557
# plain to Enigma M4 :  0.011111111111111112
# plain to Enigma :  0.03000000000000001
# Enigma to Enigma M4 :  0.05777777777777778
# Enigma to TypeX :  0.034444444444444444
# Enigma M4 to Enigma :  0.17571428571428568
# Enigma M4 to TypeX :  0.03142857142857143
# TypeX to Enigma :  0.041428571428571426
# TypeX to Enigma M4 :  0.045714285714285714
# Epoch 210000 D loss: 1.5522079467773438 G_loss: 3.3421006202697754
# Enigma to plain :  0.013333333333333334
# Enigma M4 to plain :  0.011999999999999999
# TypeX to plain :  0.027500000000000004
# plain to Enigma :  0.00375
# plain to Enigma M4 :  0.01375
# plain to Enigma :  0.016249999999999997
# Enigma to Enigma M4 :  0.03833333333333334
# Enigma to TypeX :  0.043333333333333335
# Enigma M4 to Enigma :  0.42000000000000004
# Enigma M4 to TypeX :  0.03
# TypeX to Enigma :  0.0475
# TypeX to Enigma M4 :  0.03875
# Epoch 220000 D loss: 1.659985065460205 G_loss: 1.7461493015289307
# Enigma to plain :  0.015
# Enigma M4 to plain :  0.005
# TypeX to plain :  0.02
# plain to Enigma :  0.017272727272727273
# plain to Enigma M4 :  0.005454545454545455
# plain to Enigma :  0.015454545454545455
# Enigma to Enigma M4 :  0.028749999999999998
# Enigma to TypeX :  0.04125
# Enigma M4 to Enigma :  0.4225
# Enigma M4 to TypeX :  0.03625
# TypeX to Enigma :  0.041999999999999996
# TypeX to Enigma M4 :  0.036
# Epoch 230000 D loss: 2.1341609954833984 G_loss: 3.541775703430176
# Enigma to plain :  0.016666666666666666
# Enigma M4 to plain :  0.003333333333333333
# TypeX to plain :  0.023333333333333334
# plain to Enigma :  0.02
# plain to Enigma M4 :  0.00625
# plain to Enigma :  0.01125
# Enigma to Enigma M4 :  0.03333333333333333
# Enigma to TypeX :  0.03333333333333333
# Enigma M4 to Enigma :  0.43
# Enigma M4 to TypeX :  0.03444444444444445
# TypeX to Enigma :  0.043333333333333335
# TypeX to Enigma M4 :  0.030000000000000002
# Epoch 240000 D loss: 2.304145336151123 G_loss: 1.482836127281189
# Enigma to plain :  0.026000000000000002
# Enigma M4 to plain :  0.009999999999999998
# TypeX to plain :  0.02090909090909091
# plain to Enigma :  0.01888888888888889
# plain to Enigma M4 :  0.0044444444444444444
# plain to Enigma :  0.012222222222222223
# Enigma to Enigma M4 :  0.028000000000000004
# Enigma to TypeX :  0.033999999999999996
# Enigma M4 to Enigma :  0.4057142857142857
# Enigma M4 to TypeX :  0.03571428571428571
# TypeX to Enigma :  0.046363636363636364
# TypeX to Enigma M4 :  0.03181818181818182
# Epoch 250000 D loss: 2.296708822250366 G_loss: 3.097907066345215
# Enigma to plain :  0.014444444444444446
# Enigma M4 to plain :  0.005714285714285714
# TypeX to plain :  0.026250000000000006
# plain to Enigma :  0.015
# plain to Enigma M4 :  0.0025
# plain to Enigma :  0.0125
# Enigma to Enigma M4 :  0.03333333333333334
# Enigma to TypeX :  0.04111111111111111
# Enigma M4 to Enigma :  0.4428571428571429
# Enigma M4 to TypeX :  0.04
# TypeX to Enigma :  0.045000000000000005
# TypeX to Enigma M4 :  0.028749999999999998
# Epoch 260000 D loss: 2.2278640270233154 G_loss: 1.3692984580993652
# Enigma to plain :  0.018571428571428572
# Enigma M4 to plain :  0.0071428571428571435
# TypeX to plain :  0.038571428571428576
# plain to Enigma :  0.014545454545454545
# plain to Enigma M4 :  0.002727272727272727
# plain to Enigma :  0.01636363636363636
# Enigma to Enigma M4 :  0.037142857142857144
# Enigma to TypeX :  0.032857142857142856
# Enigma M4 to Enigma :  0.42
# Enigma M4 to TypeX :  0.03428571428571429
# TypeX to Enigma :  0.055714285714285716
# TypeX to Enigma M4 :  0.028571428571428574
# Epoch 270000 D loss: 2.173518419265747 G_loss: 1.971671223640442
# Enigma to plain :  0.01875
# Enigma M4 to plain :  0.005
# TypeX to plain :  0.02428571428571429
# plain to Enigma :  0.01727272727272727
# plain to Enigma M4 :  0.004545454545454546
# plain to Enigma :  0.011818181818181818
# Enigma to Enigma M4 :  0.036250000000000004
# Enigma to TypeX :  0.03375
# Enigma M4 to Enigma :  0.4166666666666667
# Enigma M4 to TypeX :  0.021666666666666667
# TypeX to Enigma :  0.04428571428571428
# TypeX to Enigma M4 :  0.03571428571428571
# Epoch 280000 D loss: 3.2059097290039062 G_loss: 1.7691082954406738
# Enigma to plain :  0.013333333333333332
# Enigma M4 to plain :  0.0075
# TypeX to plain :  0.023333333333333334
# plain to Enigma :  0.016
# plain to Enigma M4 :  0.008
# plain to Enigma :  0.012
# Enigma to Enigma M4 :  0.03444444444444444
# Enigma to TypeX :  0.03444444444444445
# Enigma M4 to Enigma :  0.44583333333333336
# Enigma M4 to TypeX :  0.04166666666666668
# TypeX to Enigma :  0.05833333333333333
# TypeX to Enigma M4 :  0.02333333333333333
# Epoch 290000 D loss: 1.798234224319458 G_loss: 1.636936902999878
# Enigma to plain :  0.028333333333333332
# Enigma M4 to plain :  0.005833333333333334
# TypeX to plain :  0.030000000000000006
# plain to Enigma :  0.017777777777777778
# plain to Enigma M4 :  0.003333333333333333
# plain to Enigma :  0.014444444444444442
# Enigma to Enigma M4 :  0.02666666666666667
# Enigma to TypeX :  0.041666666666666664
# Enigma M4 to Enigma :  0.42249999999999993
# Enigma M4 to TypeX :  0.03166666666666666
# TypeX to Enigma :  0.041999999999999996
# TypeX to Enigma M4 :  0.034
# Epoch 300000 D loss: 2.177152395248413 G_loss: 2.578360080718994
# Enigma to plain :  0.018333333333333337
# Enigma M4 to plain :  0.0016666666666666668
# TypeX to plain :  0.027272727272727268
# plain to Enigma :  0.015555555555555557
# plain to Enigma M4 :  0.0044444444444444444
# plain to Enigma :  0.012222222222222223
# Enigma to Enigma M4 :  0.041666666666666664
# Enigma to TypeX :  0.04
# Enigma M4 to Enigma :  0.42333333333333334
# Enigma M4 to TypeX :  0.03333333333333333
# TypeX to Enigma :  0.051818181818181826
# TypeX to Enigma M4 :  0.025454545454545455
# Epoch 310000 D loss: 2.307587146759033 G_loss: 1.3741114139556885
# Enigma to plain :  0.024
# Enigma M4 to plain :  0.011000000000000001
# TypeX to plain :  0.008888888888888889
# plain to Enigma :  0.00625
# plain to Enigma M4 :  0.00625
# plain to Enigma :  0.01375
# Enigma to Enigma M4 :  0.01
# Enigma to TypeX :  0.042
# Enigma M4 to Enigma :  0.31599999999999995
# Enigma M4 to TypeX :  0.05700000000000001
# TypeX to Enigma :  0.051111111111111114
# TypeX to Enigma M4 :  0.04444444444444444
# Epoch 320000 D loss: 3.493652820587158 G_loss: 3.080636501312256
# Enigma to plain :  0.021666666666666667
# Enigma M4 to plain :  0.01
# TypeX to plain :  0.018000000000000002
# plain to Enigma :  0.012727272727272726
# plain to Enigma M4 :  0.007272727272727273
# plain to Enigma :  0.019999999999999997
# Enigma to Enigma M4 :  0.016666666666666666
# Enigma to TypeX :  0.05333333333333334
# Enigma M4 to Enigma :  0.354
# Enigma M4 to TypeX :  0.05600000000000001
# TypeX to Enigma :  0.046
# TypeX to Enigma M4 :  0.046
# Epoch 330000 D loss: 1.6593360900878906 G_loss: 1.761641502380371
# Enigma to plain :  0.017499999999999998
# Enigma M4 to plain :  0.011111111111111112
# TypeX to plain :  0.008
# plain to Enigma :  0.009999999999999998
# plain to Enigma M4 :  0.007000000000000001
# plain to Enigma :  0.019
# Enigma to Enigma M4 :  0.01375
# Enigma to TypeX :  0.051250000000000004
# Enigma M4 to Enigma :  0.3466666666666666
# Enigma M4 to TypeX :  0.05333333333333333
# TypeX to Enigma :  0.06
# TypeX to Enigma M4 :  0.04
# Epoch 340000 D loss: 2.3002099990844727 G_loss: 4.671014308929443
# Enigma to plain :  0.008571428571428572
# Enigma M4 to plain :  0.006666666666666666
# TypeX to plain :  0.026000000000000002
# plain to Enigma :  0.011666666666666667
# plain to Enigma M4 :  0.005
# plain to Enigma :  0.011666666666666667
# Enigma to Enigma M4 :  0.017142857142857144
# Enigma to TypeX :  0.038571428571428576
# Enigma M4 to Enigma :  0.44
# Enigma M4 to TypeX :  0.03666666666666666
# TypeX to Enigma :  0.056999999999999995
# TypeX to Enigma M4 :  0.051000000000000004
# Epoch 350000 D loss: 2.238340139389038 G_loss: 1.6489315032958984
# Enigma to plain :  0.006
# Enigma M4 to plain :  0.006666666666666667
# TypeX to plain :  0.018333333333333337
# plain to Enigma :  0.008571428571428572
# plain to Enigma M4 :  0.0
# plain to Enigma :  0.012857142857142857
# Enigma to Enigma M4 :  0.019999999999999997
# Enigma to TypeX :  0.043
# Enigma M4 to Enigma :  0.4044444444444444
# Enigma M4 to TypeX :  0.04666666666666667
# TypeX to Enigma :  0.06666666666666667
# TypeX to Enigma M4 :  0.049999999999999996
# Epoch 360000 D loss: 2.6629157066345215 G_loss: 3.7640459537506104
# Enigma to plain :  0.014545454545454549
# Enigma M4 to plain :  0.005555555555555556
# TypeX to plain :  0.03
# plain to Enigma :  0.03666666666666667
# plain to Enigma M4 :  0.006666666666666667
# plain to Enigma :  0.024999999999999998
# Enigma to Enigma M4 :  0.02
# Enigma to TypeX :  0.035454545454545454
# Enigma M4 to Enigma :  0.46888888888888886
# Enigma M4 to TypeX :  0.035555555555555556
# TypeX to Enigma :  0.085
# TypeX to Enigma M4 :  0.051666666666666666
# Epoch 370000 D loss: 3.3126707077026367 G_loss: 1.6277328729629517
# Enigma to plain :  0.005
# Enigma M4 to plain :  0.006923076923076922
# TypeX to plain :  0.024999999999999998
# plain to Enigma :  0.02
# plain to Enigma M4 :  0.004285714285714286
# plain to Enigma :  0.02
# Enigma to Enigma M4 :  0.018333333333333333
# Enigma to TypeX :  0.034999999999999996
# Enigma M4 to Enigma :  0.47000000000000003
# Enigma M4 to TypeX :  0.04230769230769231
# TypeX to Enigma :  0.07333333333333333
# TypeX to Enigma M4 :  0.051666666666666666
# Epoch 380000 D loss: 1.9172762632369995 G_loss: 2.0584254264831543
# Enigma to plain :  0.006666666666666667
# Enigma M4 to plain :  0.00625
# TypeX to plain :  0.02428571428571429
# plain to Enigma :  0.010909090909090908
# plain to Enigma M4 :  0.0018181818181818182
# plain to Enigma :  0.018181818181818184
# Enigma to Enigma M4 :  0.023333333333333334
# Enigma to TypeX :  0.045000000000000005
# Enigma M4 to Enigma :  0.49
# Enigma M4 to TypeX :  0.0475
# TypeX to Enigma :  0.058571428571428566
# TypeX to Enigma M4 :  0.05
# Epoch 390000 D loss: 1.8702136278152466 G_loss: 1.9163992404937744
# Enigma to plain :  0.011428571428571429
# Enigma M4 to plain :  0.004
# TypeX to plain :  0.02909090909090909
# plain to Enigma :  0.008888888888888889
# plain to Enigma M4 :  0.0022222222222222222
# plain to Enigma :  0.012222222222222223
# Enigma to Enigma M4 :  0.011428571428571429
# Enigma to TypeX :  0.05285714285714286
# Enigma M4 to Enigma :  0.5519999999999999
# Enigma M4 to TypeX :  0.052000000000000005
# TypeX to Enigma :  0.06545454545454546
# TypeX to Enigma M4 :  0.04545454545454545
# Epoch 400000 D loss: 1.5650984048843384 G_loss: 1.9451969861984253
# Enigma to plain :  0.01
# Enigma M4 to plain :  0.01111111111111111
# TypeX to plain :  0.021666666666666667
# plain to Enigma :  0.007500000000000001
# plain to Enigma M4 :  0.00375
# plain to Enigma :  0.02
# Enigma to Enigma M4 :  0.014444444444444446
# Enigma to TypeX :  0.04999999999999999
# Enigma M4 to Enigma :  0.5533333333333332
# Enigma M4 to TypeX :  0.04666666666666666
# TypeX to Enigma :  0.041666666666666664
# TypeX to Enigma M4 :  0.03500000000000001
# Epoch 410000 D loss: 2.2530405521392822 G_loss: 2.3571054935455322
# Enigma to plain :  0.012
# Enigma M4 to plain :  0.010909090909090908
# TypeX to plain :  0.02142857142857143
# plain to Enigma :  0.006666666666666666
# plain to Enigma M4 :  0.0011111111111111111
# plain to Enigma :  0.008888888888888889
# Enigma to Enigma M4 :  0.014000000000000002
# Enigma to TypeX :  0.064
# Enigma M4 to Enigma :  0.72
# Enigma M4 to TypeX :  0.05454545454545456
# TypeX to Enigma :  0.07571428571428572
# TypeX to Enigma M4 :  0.03571428571428571
# Epoch 420000 D loss: 1.7813470363616943 G_loss: 1.7547777891159058
# Enigma to plain :  0.018333333333333337
# Enigma M4 to plain :  0.008571428571428572
# TypeX to plain :  0.016666666666666666
# plain to Enigma :  0.016923076923076923
# plain to Enigma M4 :  0.0038461538461538464
# plain to Enigma :  0.006153846153846154
# Enigma to Enigma M4 :  0.03833333333333333
# Enigma to TypeX :  0.043333333333333335
# Enigma M4 to Enigma :  0.4928571428571428
# Enigma M4 to TypeX :  0.04
# TypeX to Enigma :  0.045000000000000005
# TypeX to Enigma M4 :  0.03
# Epoch 430000 D loss: 2.5344386100769043 G_loss: 2.588737964630127
# Enigma to plain :  0.031
# Enigma M4 to plain :  0.015
# TypeX to plain :  0.03166666666666667
# plain to Enigma :  0.05875
# plain to Enigma M4 :  0.026250000000000002
# plain to Enigma :  0.026250000000000002
# Enigma to Enigma M4 :  0.025
# Enigma to TypeX :  0.04
# Enigma M4 to Enigma :  0.21
# Enigma M4 to TypeX :  0.0475
# TypeX to Enigma :  0.04
# TypeX to Enigma M4 :  0.02
# Epoch 440000 D loss: 1.5007761716842651 G_loss: 2.4622678756713867
# Enigma to plain :  0.018
# Enigma M4 to plain :  0.007777777777777778
# TypeX to plain :  0.026250000000000002
# plain to Enigma :  0.012
# plain to Enigma M4 :  0.004
# plain to Enigma :  0.015
# Enigma to Enigma M4 :  0.03
# Enigma to TypeX :  0.039999999999999994
# Enigma M4 to Enigma :  0.43111111111111117
# Enigma M4 to TypeX :  0.03666666666666667
# TypeX to Enigma :  0.045
# TypeX to Enigma M4 :  0.02625
# Epoch 450000 D loss: 1.7783796787261963 G_loss: 1.868208885192871
# Enigma to plain :  0.021111111111111112
# Enigma M4 to plain :  0.003333333333333333
# TypeX to plain :  0.025
# plain to Enigma :  0.013333333333333334
# plain to Enigma M4 :  0.005
# plain to Enigma :  0.02
# Enigma to Enigma M4 :  0.02888888888888889
# Enigma to TypeX :  0.03888888888888889
# Enigma M4 to Enigma :  0.4066666666666667
# Enigma M4 to TypeX :  0.030000000000000002
# TypeX to Enigma :  0.0475
# TypeX to Enigma M4 :  0.026250000000000002
# Epoch 460000 D loss: 3.8636419773101807 G_loss: 2.052776575088501
# Enigma to plain :  0.022000000000000002
# Enigma M4 to plain :  0.006363636363636364
# TypeX to plain :  0.02666666666666666
# plain to Enigma :  0.017142857142857144
# plain to Enigma M4 :  0.004285714285714286
# plain to Enigma :  0.01
# Enigma to Enigma M4 :  0.022
# Enigma to TypeX :  0.052000000000000005
# Enigma M4 to Enigma :  0.4418181818181818
# Enigma M4 to TypeX :  0.030000000000000002
# TypeX to Enigma :  0.042222222222222223
# TypeX to Enigma M4 :  0.03333333333333333
# Epoch 470000 D loss: 1.1343787908554077 G_loss: 1.7955162525177002
# Enigma to plain :  0.027142857142857146
# Enigma M4 to plain :  0.007272727272727273
# TypeX to plain :  0.028333333333333332
# plain to Enigma :  0.015000000000000001
# plain to Enigma M4 :  0.0025
# plain to Enigma :  0.0175
# Enigma to Enigma M4 :  0.02857142857142857
# Enigma to TypeX :  0.03
# Enigma M4 to Enigma :  0.42909090909090913
# Enigma M4 to TypeX :  0.03363636363636364
# TypeX to Enigma :  0.043333333333333335
# TypeX to Enigma M4 :  0.023333333333333334
# Epoch 480000 D loss: 1.0833673477172852 G_loss: 3.1944446563720703
# Enigma to plain :  0.016666666666666666
# Enigma M4 to plain :  0.0044444444444444444
# TypeX to plain :  0.024999999999999998
# plain to Enigma :  0.02
# plain to Enigma M4 :  0.005555555555555556
# plain to Enigma :  0.01
# Enigma to Enigma M4 :  0.03333333333333333
# Enigma to TypeX :  0.043333333333333335
# Enigma M4 to Enigma :  0.42777777777777776
# Enigma M4 to TypeX :  0.03333333333333333
# TypeX to Enigma :  0.04
# TypeX to Enigma M4 :  0.028749999999999998
# Epoch 490000 D loss: 1.4187169075012207 G_loss: 1.413160800933838
# Enigma to plain :  0.017142857142857144
# Enigma M4 to plain :  0.008888888888888889
# TypeX to plain :  0.024999999999999998
# plain to Enigma :  0.0225
# plain to Enigma M4 :  0.00625
# plain to Enigma :  0.01125
# Enigma to Enigma M4 :  0.028571428571428574
# Enigma to TypeX :  0.03571428571428571
# Enigma M4 to Enigma :  0.4388888888888889
# Enigma M4 to TypeX :  0.034444444444444444
# TypeX to Enigma :  0.04375
# TypeX to Enigma M4 :  0.030000000000000002
# Epoch 500000 D loss: 3.0168471336364746 G_loss: 4.448551654815674
# Enigma to plain :  0.020999999999999998
# Enigma M4 to plain :  0.00125
# TypeX to plain :  0.03571428571428571
# plain to Enigma :  0.019999999999999997
# plain to Enigma M4 :  0.004285714285714286
# plain to Enigma :  0.012857142857142857
# Enigma to Enigma M4 :  0.029000000000000005
# Enigma to TypeX :  0.042
# Enigma M4 to Enigma :  0.41875
# Enigma M4 to TypeX :  0.0275
# TypeX to Enigma :  0.05285714285714286
# TypeX to Enigma M4 :  0.02571428571428571
# Epoch 510000 D loss: 1.8850728273391724 G_loss: 2.222412109375
# Enigma to plain :  0.015
# Enigma M4 to plain :  0.013333333333333334
# TypeX to plain :  0.033
# plain to Enigma :  0.013333333333333334
# plain to Enigma M4 :  0.0044444444444444444
# plain to Enigma :  0.012222222222222223
# Enigma to Enigma M4 :  0.031
# Enigma to TypeX :  0.044
# Enigma M4 to Enigma :  0.42333333333333334
# Enigma M4 to TypeX :  0.03333333333333333
# TypeX to Enigma :  0.041999999999999996
# TypeX to Enigma M4 :  0.02
# Epoch 520000 D loss: 3.610471248626709 G_loss: 4.890814304351807
# Enigma to plain :  0.016666666666666666
# Enigma M4 to plain :  0.00625
# TypeX to plain :  0.025454545454545455
# plain to Enigma :  0.017142857142857144
# plain to Enigma M4 :  0.0071428571428571435
# plain to Enigma :  0.011428571428571429
# Enigma to Enigma M4 :  0.015
# Enigma to TypeX :  0.03333333333333333
# Enigma M4 to Enigma :  0.2125
# Enigma M4 to TypeX :  0.0525
# TypeX to Enigma :  0.05
# TypeX to Enigma M4 :  0.042727272727272725
# Epoch 530000 D loss: 2.5698604583740234 G_loss: 3.3835177421569824
# Enigma to plain :  0.015833333333333335
# Enigma M4 to plain :  0.01
# TypeX to plain :  0.03666666666666667
# plain to Enigma :  0.02
# plain to Enigma M4 :  0.012
# plain to Enigma :  0.044
# Enigma to Enigma M4 :  0.028333333333333335
# Enigma to TypeX :  0.024166666666666666
# Enigma M4 to Enigma :  0.0
# Enigma M4 to TypeX :  0.02666666666666667
# TypeX to Enigma :  0.03222222222222223
# TypeX to Enigma M4 :  0.03777777777777777
# Epoch 540000 D loss: 3.327317714691162 G_loss: 4.6067423820495605
# Enigma to plain :  0.021111111111111112
# Enigma M4 to plain :  0.012
# TypeX to plain :  0.03375
# plain to Enigma :  0.019
# plain to Enigma M4 :  0.011
# plain to Enigma :  0.03300000000000001
# Enigma to Enigma M4 :  0.035555555555555556
# Enigma to TypeX :  0.03444444444444445
# Enigma M4 to Enigma :  0.048
# Enigma M4 to TypeX :  0.034
# TypeX to Enigma :  0.027500000000000004
# TypeX to Enigma M4 :  0.036250000000000004
# Epoch 550000 D loss: 4.488293647766113 G_loss: 2.2127158641815186
# Enigma to plain :  0.025
# Enigma M4 to plain :  0.012
# TypeX to plain :  0.05333333333333334
# plain to Enigma :  0.022222222222222223
# plain to Enigma M4 :  0.008888888888888889
# plain to Enigma :  0.03222222222222223
# Enigma to Enigma M4 :  0.026000000000000002
# Enigma to TypeX :  0.03
# Enigma M4 to Enigma :  0.051000000000000004
# Enigma M4 to TypeX :  0.030000000000000006
# TypeX to Enigma :  0.05000000000000001
# TypeX to Enigma M4 :  0.03
# Epoch 560000 D loss: 1.5632703304290771 G_loss: 3.8380637168884277
# Enigma to plain :  0.027142857142857142
# Enigma M4 to plain :  0.011428571428571427
# TypeX to plain :  0.04727272727272727
# plain to Enigma :  0.02142857142857143
# plain to Enigma M4 :  0.002857142857142857
# plain to Enigma :  0.017142857142857144
# Enigma to Enigma M4 :  0.03142857142857143
# Enigma to TypeX :  0.038571428571428576
# Enigma M4 to Enigma :  0.3885714285714285
# Enigma M4 to TypeX :  0.032857142857142856
# TypeX to Enigma :  0.0409090909090909
# TypeX to Enigma M4 :  0.028181818181818183
# Epoch 570000 D loss: 1.2452982664108276 G_loss: 1.9683842658996582
# Enigma to plain :  0.0275
# Enigma M4 to plain :  0.018333333333333337
# TypeX to plain :  0.03909090909090909
# plain to Enigma :  0.018571428571428572
# plain to Enigma M4 :  0.01
# plain to Enigma :  0.032857142857142856
# Enigma to Enigma M4 :  0.020000000000000004
# Enigma to TypeX :  0.01875
# Enigma M4 to Enigma :  0.13833333333333334
# Enigma M4 to TypeX :  0.02666666666666667
# TypeX to Enigma :  0.034545454545454546
# TypeX to Enigma M4 :  0.03636363636363637
# Epoch 580000 D loss: 1.2686452865600586 G_loss: 2.8004486560821533
# Enigma to plain :  0.0225
# Enigma M4 to plain :  0.012999999999999998
# TypeX to plain :  0.041666666666666664
# plain to Enigma :  0.042499999999999996
# plain to Enigma M4 :  0.015
# plain to Enigma :  0.04
# Enigma to Enigma M4 :  0.02875
# Enigma to TypeX :  0.0275
# Enigma M4 to Enigma :  0.164
# Enigma M4 to TypeX :  0.03400000000000001
# TypeX to Enigma :  0.03833333333333334
# TypeX to Enigma M4 :  0.023333333333333334
# Epoch 590000 D loss: 1.5379053354263306 G_loss: 3.6119513511657715
# Enigma to plain :  0.026000000000000002
# Enigma M4 to plain :  0.0325
# TypeX to plain :  0.0375
# plain to Enigma :  0.018571428571428572
# plain to Enigma M4 :  0.017142857142857144
# plain to Enigma :  0.042857142857142864
# Enigma to Enigma M4 :  0.03
# Enigma to TypeX :  0.022
# Enigma M4 to Enigma :  0.05625
# Enigma M4 to TypeX :  0.0325
# TypeX to Enigma :  0.045000000000000005
# TypeX to Enigma M4 :  0.03416666666666667
# Epoch 600000 D loss: 1.6838067770004272 G_loss: 2.386491298675537
# Enigma to plain :  0.027692307692307697
# Enigma M4 to plain :  0.026000000000000002
# TypeX to plain :  0.03333333333333333
# plain to Enigma :  0.02
# plain to Enigma M4 :  0.013999999999999999
# plain to Enigma :  0.044000000000000004
# Enigma to Enigma M4 :  0.03153846153846153
# Enigma to TypeX :  0.02538461538461538
# Enigma M4 to Enigma :  0.06999999999999999
# Enigma M4 to TypeX :  0.02
# TypeX to Enigma :  0.03888888888888889
# TypeX to Enigma M4 :  0.035555555555555556
# Epoch 610000 D loss: 3.433598041534424 G_loss: 2.813448905944824
# Enigma to plain :  0.029166666666666664
# Enigma M4 to plain :  0.042
# TypeX to plain :  0.03142857142857143
# plain to Enigma :  0.01875
# plain to Enigma M4 :  0.01125
# plain to Enigma :  0.03875000000000001
# Enigma to Enigma M4 :  0.023333333333333334
# Enigma to TypeX :  0.02666666666666667
# Enigma M4 to Enigma :  0.064
# Enigma M4 to TypeX :  0.034
# TypeX to Enigma :  0.03428571428571429
# TypeX to Enigma M4 :  0.02857142857142857
# Epoch 620000 D loss: 0.7875039577484131 G_loss: 2.892625331878662
# Enigma to plain :  0.027142857142857142
# Enigma M4 to plain :  0.02
# TypeX to plain :  0.035833333333333335
# plain to Enigma :  0.018888888888888886
# plain to Enigma M4 :  0.003333333333333333
# plain to Enigma :  0.031111111111111114
# Enigma to Enigma M4 :  0.022857142857142857
# Enigma to TypeX :  0.02428571428571429
# Enigma M4 to Enigma :  0.16749999999999998
# Enigma M4 to TypeX :  0.025
# TypeX to Enigma :  0.024166666666666666
# TypeX to Enigma M4 :  0.0325
# Epoch 630000 D loss: 0.7408271431922913 G_loss: 2.5378408432006836
# Enigma to plain :  0.025000000000000005
# Enigma M4 to plain :  0.01625
# TypeX to plain :  0.030000000000000002
# plain to Enigma :  0.02
# plain to Enigma M4 :  0.0044444444444444444
# plain to Enigma :  0.03222222222222222
# Enigma to Enigma M4 :  0.021666666666666667
# Enigma to TypeX :  0.023333333333333334
# Enigma M4 to Enigma :  0.1525
# Enigma M4 to TypeX :  0.027500000000000004
# TypeX to Enigma :  0.025555555555555557
# TypeX to Enigma M4 :  0.034444444444444444
# Epoch 640000 D loss: 0.7929913401603699 G_loss: 2.9540295600891113
# Enigma to plain :  0.022000000000000002
# Enigma M4 to plain :  0.01125
# TypeX to plain :  0.031111111111111114
# plain to Enigma :  0.018
# plain to Enigma M4 :  0.006999999999999999
# plain to Enigma :  0.026000000000000002
# Enigma to Enigma M4 :  0.014000000000000002
# Enigma to TypeX :  0.024
# Enigma M4 to Enigma :  0.19874999999999998
# Enigma M4 to TypeX :  0.02875
# TypeX to Enigma :  0.027777777777777776
# TypeX to Enigma M4 :  0.02888888888888889
# Epoch 650000 D loss: 1.0401802062988281 G_loss: 2.0629892349243164
# Enigma to plain :  0.024285714285714282
# Enigma M4 to plain :  0.015000000000000001
# TypeX to plain :  0.037000000000000005
# plain to Enigma :  0.017777777777777778
# plain to Enigma M4 :  0.008888888888888889
# plain to Enigma :  0.031111111111111107
# Enigma to Enigma M4 :  0.027142857142857146
# Enigma to TypeX :  0.03
# Enigma M4 to Enigma :  0.15
# Enigma M4 to TypeX :  0.03833333333333334
# TypeX to Enigma :  0.031
# TypeX to Enigma M4 :  0.027999999999999997
# Epoch 660000 D loss: 1.6632455587387085 G_loss: 2.7792422771453857
# Enigma to plain :  0.031111111111111114
# Enigma M4 to plain :  0.015
# TypeX to plain :  0.040999999999999995
# plain to Enigma :  0.02
# plain to Enigma M4 :  0.01
# plain to Enigma :  0.017142857142857144
# Enigma to Enigma M4 :  0.027777777777777776
# Enigma to TypeX :  0.022222222222222223
# Enigma M4 to Enigma :  0.21333333333333335
# Enigma M4 to TypeX :  0.03166666666666667
# TypeX to Enigma :  0.038
# TypeX to Enigma M4 :  0.031999999999999994
# Epoch 670000 D loss: 3.628232955932617 G_loss: 3.18928861618042
# Enigma to plain :  0.027142857142857142
# Enigma M4 to plain :  0.01
# TypeX to plain :  0.015384615384615385
# plain to Enigma :  0.036666666666666674
# plain to Enigma M4 :  0.01
# plain to Enigma :  0.03166666666666667
# Enigma to Enigma M4 :  0.022857142857142857
# Enigma to TypeX :  0.011428571428571429
# Enigma M4 to Enigma :  0.2783333333333334
# Enigma M4 to TypeX :  0.02
# TypeX to Enigma :  0.04307692307692308
# TypeX to Enigma M4 :  0.02692307692307693
# Epoch 680000 D loss: 1.7992340326309204 G_loss: 4.270879745483398
# Enigma to plain :  0.03
# Enigma M4 to plain :  0.028571428571428574
# TypeX to plain :  0.022
# plain to Enigma :  0.034999999999999996
# plain to Enigma M4 :  0.01625
# plain to Enigma :  0.022500000000000003
# Enigma to Enigma M4 :  0.02428571428571429
# Enigma to TypeX :  0.022857142857142857
# Enigma M4 to Enigma :  0.24
# Enigma M4 to TypeX :  0.032857142857142856
# TypeX to Enigma :  0.048999999999999995
# TypeX to Enigma M4 :  0.029000000000000005
# Epoch 690000 D loss: 2.5378799438476562 G_loss: 1.8704975843429565
# Enigma to plain :  0.024444444444444446
# Enigma M4 to plain :  0.015
# TypeX to plain :  0.01375
# plain to Enigma :  0.03857142857142857
# plain to Enigma M4 :  0.012857142857142857
# plain to Enigma :  0.03
# Enigma to Enigma M4 :  0.024444444444444446
# Enigma to TypeX :  0.021111111111111112
# Enigma M4 to Enigma :  0.225
# Enigma M4 to TypeX :  0.0225
# TypeX to Enigma :  0.0375
# TypeX to Enigma M4 :  0.035
# Epoch 700000 D loss: 1.5029222965240479 G_loss: 3.471190929412842
# Enigma to plain :  0.03888888888888889
# Enigma M4 to plain :  0.011250000000000001
# TypeX to plain :  0.021111111111111112
# plain to Enigma :  0.03333333333333333
# plain to Enigma M4 :  0.016666666666666666
# plain to Enigma :  0.015
# Enigma to Enigma M4 :  0.027777777777777776
# Enigma to TypeX :  0.01888888888888889
# Enigma M4 to Enigma :  0.2425
# Enigma M4 to TypeX :  0.028749999999999998
# TypeX to Enigma :  0.03222222222222222
# TypeX to Enigma M4 :  0.020000000000000004
# Epoch 710000 D loss: 2.011080741882324 G_loss: 1.6160626411437988
# Enigma to plain :  0.034444444444444444
# Enigma M4 to plain :  0.015555555555555553
# TypeX to plain :  0.0125
# plain to Enigma :  0.03666666666666667
# plain to Enigma M4 :  0.016666666666666666
# plain to Enigma :  0.049999999999999996
# Enigma to Enigma M4 :  0.024444444444444446
# Enigma to TypeX :  0.03444444444444444
# Enigma M4 to Enigma :  0.22444444444444445
# Enigma M4 to TypeX :  0.03333333333333333
# TypeX to Enigma :  0.03375
# TypeX to Enigma M4 :  0.02
# Epoch 720000 D loss: 0.909220814704895 G_loss: 2.411289930343628
# Enigma to plain :  0.027777777777777776
# Enigma M4 to plain :  0.016666666666666666
# TypeX to plain :  0.018571428571428572
# plain to Enigma :  0.045714285714285714
# plain to Enigma M4 :  0.014285714285714287
# plain to Enigma :  0.02857142857142857
# Enigma to Enigma M4 :  0.017777777777777778
# Enigma to TypeX :  0.016666666666666666
# Enigma M4 to Enigma :  0.2733333333333333
# Enigma M4 to TypeX :  0.02
# TypeX to Enigma :  0.038571428571428576
# TypeX to Enigma M4 :  0.028571428571428574
# Epoch 730000 D loss: 1.2515180110931396 G_loss: 1.6717203855514526
# Enigma to plain :  0.019166666666666665
# Enigma M4 to plain :  0.015
# TypeX to plain :  0.025000000000000005
# plain to Enigma :  0.019999999999999997
# plain to Enigma M4 :  0.006
# plain to Enigma :  0.021
# Enigma to Enigma M4 :  0.028333333333333332
# Enigma to TypeX :  0.02416666666666667
# Enigma M4 to Enigma :  0.17250000000000001
# Enigma M4 to TypeX :  0.037500000000000006
# TypeX to Enigma :  0.02
# TypeX to Enigma M4 :  0.043333333333333335
# Epoch 740000 D loss: 1.297595500946045 G_loss: 2.2176549434661865
# Enigma to plain :  0.027999999999999997
# Enigma M4 to plain :  0.006666666666666667
# TypeX to plain :  0.030000000000000002
# plain to Enigma :  0.016
# plain to Enigma M4 :  0.003
# plain to Enigma :  0.018000000000000002
# Enigma to Enigma M4 :  0.028000000000000004
# Enigma to TypeX :  0.034999999999999996
# Enigma M4 to Enigma :  0.3833333333333333
# Enigma M4 to TypeX :  0.035
# TypeX to Enigma :  0.03166666666666667
# TypeX to Enigma M4 :  0.016666666666666666
# Epoch 750000 D loss: 1.3974984884262085 G_loss: 2.818058490753174
# Enigma to plain :  0.026000000000000002
# Enigma M4 to plain :  0.01
# TypeX to plain :  0.03333333333333333
# plain to Enigma :  0.017857142857142856
# plain to Enigma M4 :  0.0035714285714285718
# plain to Enigma :  0.012857142857142857
# Enigma to Enigma M4 :  0.029000000000000005
# Enigma to TypeX :  0.04400000000000001
# Enigma M4 to Enigma :  0.31000000000000005
# Enigma M4 to TypeX :  0.035
# TypeX to Enigma :  0.03666666666666667
# TypeX to Enigma M4 :  0.028333333333333335
# Epoch 760000 D loss: 1.5387814044952393 G_loss: 1.4098387956619263
# Enigma to plain :  0.030000000000000006
# Enigma M4 to plain :  0.01
# TypeX to plain :  0.037500000000000006
# plain to Enigma :  0.017777777777777778
# plain to Enigma M4 :  0.006666666666666667
# plain to Enigma :  0.01111111111111111
# Enigma to Enigma M4 :  0.03400000000000001
# Enigma to TypeX :  0.030000000000000006
# Enigma M4 to Enigma :  0.396
# Enigma M4 to TypeX :  0.033999999999999996
# TypeX to Enigma :  0.0475
# TypeX to Enigma M4 :  0.0275
# Epoch 770000 D loss: 3.6878488063812256 G_loss: 4.2019453048706055
# Enigma to plain :  0.015555555555555557
# Enigma M4 to plain :  0.011249999999999998
# TypeX to plain :  0.038571428571428576
# plain to Enigma :  0.01625
# plain to Enigma M4 :  0.01
# plain to Enigma :  0.0175
# Enigma to Enigma M4 :  0.02222222222222222
# Enigma to TypeX :  0.018888888888888886
# Enigma M4 to Enigma :  0.13125
# Enigma M4 to TypeX :  0.023750000000000004
# TypeX to Enigma :  0.025714285714285714
# TypeX to Enigma M4 :  0.038571428571428576
# Epoch 780000 D loss: 1.3960763216018677 G_loss: 1.7314624786376953
# Enigma to plain :  0.018333333333333333
# Enigma M4 to plain :  0.014000000000000002
# TypeX to plain :  0.025
# plain to Enigma :  0.01625
# plain to Enigma M4 :  0.00375
# plain to Enigma :  0.01625
# Enigma to Enigma M4 :  0.034999999999999996
# Enigma to TypeX :  0.03333333333333333
# Enigma M4 to Enigma :  0.375
# Enigma M4 to TypeX :  0.031
# TypeX to Enigma :  0.043750000000000004
# TypeX to Enigma M4 :  0.027500000000000004
# Epoch 790000 D loss: 1.9601514339447021 G_loss: 4.109936237335205
# Enigma to plain :  0.028000000000000004
# Enigma M4 to plain :  0.012727272727272728
# TypeX to plain :  0.019999999999999997
# plain to Enigma :  0.01909090909090909
# plain to Enigma M4 :  0.005454545454545455
# plain to Enigma :  0.017272727272727273
# Enigma to Enigma M4 :  0.024
# Enigma to TypeX :  0.03
# Enigma M4 to Enigma :  0.3090909090909091
# Enigma M4 to TypeX :  0.024545454545454547
# TypeX to Enigma :  0.033999999999999996
# TypeX to Enigma M4 :  0.036000000000000004
# Epoch 800000 D loss: 1.9242349863052368 G_loss: 1.2865641117095947
# Enigma to plain :  0.022
# Enigma M4 to plain :  0.014545454545454544
# TypeX to plain :  0.037500000000000006
# plain to Enigma :  0.02125
# plain to Enigma M4 :  0.00375
# plain to Enigma :  0.01875
# Enigma to Enigma M4 :  0.016
# Enigma to TypeX :  0.036000000000000004
# Enigma M4 to Enigma :  0.28818181818181826
# Enigma M4 to TypeX :  0.017272727272727273
# TypeX to Enigma :  0.03
# TypeX to Enigma M4 :  0.027499999999999997
# Epoch 810000 D loss: 1.0442371368408203 G_loss: 1.9532861709594727
# Enigma to plain :  0.022
# Enigma M4 to plain :  0.012
# TypeX to plain :  0.029090909090909098
# plain to Enigma :  0.02
# plain to Enigma M4 :  0.0033333333333333335
# plain to Enigma :  0.02
# Enigma to Enigma M4 :  0.020000000000000004
# Enigma to TypeX :  0.018
# Enigma M4 to Enigma :  0.16799999999999998
# Enigma M4 to TypeX :  0.022
# TypeX to Enigma :  0.03090909090909091
# TypeX to Enigma M4 :  0.035454545454545454
# Epoch 820000 D loss: 1.1318998336791992 G_loss: 1.768355369567871
# Enigma to plain :  0.025
# Enigma M4 to plain :  0.013999999999999999
# TypeX to plain :  0.021666666666666667
# plain to Enigma :  0.03230769230769231
# plain to Enigma M4 :  0.01153846153846154
# plain to Enigma :  0.03307692307692309
# Enigma to Enigma M4 :  0.03125
# Enigma to TypeX :  0.028749999999999998
# Enigma M4 to Enigma :  0.064
# Enigma M4 to TypeX :  0.038000000000000006
# TypeX to Enigma :  0.04833333333333334
# TypeX to Enigma M4 :  0.03833333333333334
# Epoch 830000 D loss: 0.9528238773345947 G_loss: 2.5889618396759033
# Enigma to plain :  0.01916666666666667
# Enigma M4 to plain :  0.0075
# TypeX to plain :  0.03428571428571429
# plain to Enigma :  0.018888888888888886
# plain to Enigma M4 :  0.003333333333333333
# plain to Enigma :  0.010000000000000002
# Enigma to Enigma M4 :  0.03333333333333333
# Enigma to TypeX :  0.04083333333333333
# Enigma M4 to Enigma :  0.36250000000000004
# Enigma M4 to TypeX :  0.045000000000000005
# TypeX to Enigma :  0.038571428571428576
# TypeX to Enigma M4 :  0.02142857142857143
# Epoch 840000 D loss: 1.1743088960647583 G_loss: 4.254060745239258
# Enigma to plain :  0.01625
# Enigma M4 to plain :  0.004
# TypeX to plain :  0.03166666666666667
# plain to Enigma :  0.02
# plain to Enigma M4 :  0.0025
# plain to Enigma :  0.01625
# Enigma to Enigma M4 :  0.03
# Enigma to TypeX :  0.04
# Enigma M4 to Enigma :  0.41800000000000004
# Enigma M4 to TypeX :  0.033
# TypeX to Enigma :  0.04
# TypeX to Enigma M4 :  0.023333333333333334
# Epoch 850000 D loss: 0.4535439610481262 G_loss: 1.6678366661071777
# Enigma to plain :  0.0125
# Enigma M4 to plain :  0.007777777777777778
# TypeX to plain :  0.028000000000000004
# plain to Enigma :  0.012
# plain to Enigma M4 :  0.006
# plain to Enigma :  0.01
# Enigma to Enigma M4 :  0.028749999999999998
# Enigma to TypeX :  0.046250000000000006
# Enigma M4 to Enigma :  0.4488888888888889
# Enigma M4 to TypeX :  0.036666666666666674
# TypeX to Enigma :  0.044
# TypeX to Enigma M4 :  0.026000000000000002
# Epoch 860000 D loss: 0.7221695184707642 G_loss: 4.620848178863525
# Enigma to plain :  0.024
# Enigma M4 to plain :  0.01125
# TypeX to plain :  0.035
# plain to Enigma :  0.026250000000000002
# plain to Enigma M4 :  0.00125
# plain to Enigma :  0.021249999999999998
# Enigma to Enigma M4 :  0.039999999999999994
# Enigma to TypeX :  0.029000000000000005
# Enigma M4 to Enigma :  0.35124999999999995
# Enigma M4 to TypeX :  0.025
# TypeX to Enigma :  0.028333333333333335
# TypeX to Enigma M4 :  0.023333333333333334
# Epoch 870000 D loss: 1.2500755786895752 G_loss: 1.265609860420227
# Enigma to plain :  0.02571428571428571
# Enigma M4 to plain :  0.013999999999999999
# TypeX to plain :  0.037142857142857144
# plain to Enigma :  0.017499999999999998
# plain to Enigma M4 :  0.00375
# plain to Enigma :  0.0225
# Enigma to Enigma M4 :  0.03142857142857143
# Enigma to TypeX :  0.02857142857142857
# Enigma M4 to Enigma :  0.30999999999999994
# Enigma M4 to TypeX :  0.027000000000000003
# TypeX to Enigma :  0.03428571428571429
# TypeX to Enigma M4 :  0.022857142857142857
# Epoch 880000 D loss: 2.586602210998535 G_loss: 3.5478625297546387
# Enigma to plain :  0.027777777777777776
# Enigma M4 to plain :  0.012727272727272726
# TypeX to plain :  0.03333333333333333
# plain to Enigma :  0.015
# plain to Enigma M4 :  0.0033333333333333335
# plain to Enigma :  0.015
# Enigma to Enigma M4 :  0.024444444444444446
# Enigma to TypeX :  0.035555555555555556
# Enigma M4 to Enigma :  0.42545454545454553
# Enigma M4 to TypeX :  0.035454545454545454
# TypeX to Enigma :  0.03333333333333333
# TypeX to Enigma M4 :  0.02666666666666667
# Epoch 890000 D loss: 0.6386213302612305 G_loss: 0.9833769202232361
# Enigma to plain :  0.02727272727272727
# Enigma M4 to plain :  0.01
# TypeX to plain :  0.031111111111111114
# plain to Enigma :  0.011428571428571429
# plain to Enigma M4 :  0.0
# plain to Enigma :  0.015714285714285715
# Enigma to Enigma M4 :  0.030000000000000006
# Enigma to TypeX :  0.03727272727272727
# Enigma M4 to Enigma :  0.31000000000000005
# Enigma M4 to TypeX :  0.036000000000000004
# TypeX to Enigma :  0.03555555555555556
# TypeX to Enigma M4 :  0.031111111111111114
# Epoch 900000 D loss: 0.8110295534133911 G_loss: 3.7080461978912354
# Enigma to plain :  0.02428571428571429
# Enigma M4 to plain :  0.01
# TypeX to plain :  0.02846153846153846
# plain to Enigma :  0.019999999999999997
# plain to Enigma M4 :  0.005
# plain to Enigma :  0.022500000000000003
# Enigma to Enigma M4 :  0.022857142857142857
# Enigma to TypeX :  0.030000000000000002
# Enigma M4 to Enigma :  0.125
# Enigma M4 to TypeX :  0.0275
# TypeX to Enigma :  0.03076923076923077
# TypeX to Enigma M4 :  0.030769230769230774
# Epoch 910000 D loss: 0.8021930456161499 G_loss: 1.2889033555984497
# Enigma to plain :  0.022222222222222223
# Enigma M4 to plain :  0.01125
# TypeX to plain :  0.038571428571428576
# plain to Enigma :  0.01125
# plain to Enigma M4 :  0.00125
# plain to Enigma :  0.013749999999999998
# Enigma to Enigma M4 :  0.027777777777777776
# Enigma to TypeX :  0.04888888888888889
# Enigma M4 to Enigma :  0.4150000000000001
# Enigma M4 to TypeX :  0.03875
# TypeX to Enigma :  0.06285714285714286
# TypeX to Enigma M4 :  0.018571428571428572
# Epoch 920000 D loss: 0.7099219560623169 G_loss: 2.637394666671753
# Enigma to plain :  0.021666666666666667
# Enigma M4 to plain :  0.011666666666666667
# TypeX to plain :  0.032857142857142856
# plain to Enigma :  0.02076923076923077
# plain to Enigma M4 :  0.0038461538461538464
# plain to Enigma :  0.01230769230769231
# Enigma to Enigma M4 :  0.028333333333333335
# Enigma to TypeX :  0.03166666666666667
# Enigma M4 to Enigma :  0.30333333333333334
# Enigma M4 to TypeX :  0.02666666666666667
# TypeX to Enigma :  0.027142857142857142
# TypeX to Enigma M4 :  0.028571428571428574
# Epoch 930000 D loss: 0.9444752335548401 G_loss: 1.400510311126709
# Enigma to plain :  0.018333333333333333
# Enigma M4 to plain :  0.016666666666666666
# TypeX to plain :  0.030000000000000002
# plain to Enigma :  0.01727272727272727
# plain to Enigma M4 :  0.006363636363636364
# plain to Enigma :  0.01818181818181818
# Enigma to Enigma M4 :  0.028333333333333335
# Enigma to TypeX :  0.03833333333333334
# Enigma M4 to Enigma :  0.24222222222222223
# Enigma M4 to TypeX :  0.03333333333333333
# TypeX to Enigma :  0.03
# TypeX to Enigma M4 :  0.021666666666666664
# Epoch 940000 D loss: 0.6215757131576538 G_loss: 1.578220248222351
# Enigma to plain :  0.025
# Enigma M4 to plain :  0.01
# TypeX to plain :  0.03666666666666667
# plain to Enigma :  0.015833333333333335
# plain to Enigma M4 :  0.0025
# plain to Enigma :  0.012499999999999999
# Enigma to Enigma M4 :  0.0325
# Enigma to TypeX :  0.037500000000000006
# Enigma M4 to Enigma :  0.333
# Enigma M4 to TypeX :  0.026000000000000002
# TypeX to Enigma :  0.05000000000000001
# TypeX to Enigma M4 :  0.023333333333333334
# Epoch 950000 D loss: 1.0202490091323853 G_loss: 2.054025888442993
# Enigma to plain :  0.015555555555555557
# Enigma M4 to plain :  0.01
# TypeX to plain :  0.014444444444444446
# plain to Enigma :  0.03444444444444445
# plain to Enigma M4 :  0.02111111111111111
# plain to Enigma :  0.02888888888888889
# Enigma to Enigma M4 :  0.022222222222222223
# Enigma to TypeX :  0.02
# Enigma M4 to Enigma :  0.21000000000000002
# Enigma M4 to TypeX :  0.026000000000000002
# TypeX to Enigma :  0.05222222222222222
# TypeX to Enigma M4 :  0.022222222222222223
# Epoch 960000 D loss: 0.8687049150466919 G_loss: 1.96620512008667
# Enigma to plain :  0.02888888888888889
# Enigma M4 to plain :  0.0071428571428571435
# TypeX to plain :  0.01916666666666667
# plain to Enigma :  0.05
# plain to Enigma M4 :  0.0025
# plain to Enigma :  0.0225
# Enigma to Enigma M4 :  0.03333333333333333
# Enigma to TypeX :  0.037777777777777785
# Enigma M4 to Enigma :  0.12
# Enigma M4 to TypeX :  0.03571428571428571
# TypeX to Enigma :  0.04083333333333334
# TypeX to Enigma M4 :  0.021666666666666667
# Epoch 970000 D loss: 1.5647141933441162 G_loss: 1.981203556060791
# Enigma to plain :  0.024
# Enigma M4 to plain :  0.016
# TypeX to plain :  0.02538461538461539
# plain to Enigma :  0.021111111111111112
# plain to Enigma M4 :  0.003333333333333333
# plain to Enigma :  0.015555555555555557
# Enigma to Enigma M4 :  0.033999999999999996
# Enigma to TypeX :  0.032
# Enigma M4 to Enigma :  0.176
# Enigma M4 to TypeX :  0.030000000000000006
# TypeX to Enigma :  0.05076923076923078
# TypeX to Enigma M4 :  0.02846153846153846
# Epoch 980000 D loss: 0.5268082618713379 G_loss: 1.4683860540390015
# Enigma to plain :  0.01
# Enigma M4 to plain :  0.014545454545454545
# TypeX to plain :  0.021111111111111112
# plain to Enigma :  0.03333333333333333
# plain to Enigma M4 :  0.005
# plain to Enigma :  0.02666666666666666
# Enigma to Enigma M4 :  0.03666666666666667
# Enigma to TypeX :  0.03166666666666667
# Enigma M4 to Enigma :  0.11999999999999998
# Enigma M4 to TypeX :  0.030000000000000002
# TypeX to Enigma :  0.041111111111111105
# TypeX to Enigma M4 :  0.01666666666666667
# Epoch 990000 D loss: 0.46268337965011597 G_loss: 2.5673928260803223
# Enigma to plain :  0.032857142857142856
# Enigma M4 to plain :  0.016666666666666666
# TypeX to plain :  0.025
# plain to Enigma :  0.04222222222222222
# plain to Enigma M4 :  0.008888888888888889
# plain to Enigma :  0.01111111111111111
# Enigma to Enigma M4 :  0.025714285714285714
# Enigma to TypeX :  0.04
# Enigma M4 to Enigma :  0.31833333333333336
# Enigma M4 to TypeX :  0.03833333333333334
# TypeX to Enigma :  0.045
# TypeX to Enigma M4 :  0.013000000000000001
# Epoch 1000000 D loss: 0.7064611315727234 G_loss: 2.366706609725952
# Enigma to plain :  0.02428571428571429
# Enigma M4 to plain :  0.007500000000000001
# TypeX to plain :  0.022222222222222223
# plain to Enigma :  0.01625
# plain to Enigma M4 :  0.005
# plain to Enigma :  0.007500000000000001
# Enigma to Enigma M4 :  0.041428571428571426
# Enigma to TypeX :  0.04
# Enigma M4 to Enigma :  0.3712499999999999
# Enigma M4 to TypeX :  0.041249999999999995
# TypeX to Enigma :  0.026666666666666665
# TypeX to Enigma M4 :  0.026666666666666665
# Epoch 1010000 D loss: 1.7490622997283936 G_loss: 3.7203269004821777
# Enigma to plain :  0.028333333333333332
# Enigma M4 to plain :  0.0175
# TypeX to plain :  0.01909090909090909
# plain to Enigma :  0.04857142857142858
# plain to Enigma M4 :  0.024285714285714282
# plain to Enigma :  0.04142857142857143
# Enigma to Enigma M4 :  0.01833333333333333
# Enigma to TypeX :  0.023333333333333334
# Enigma M4 to Enigma :  0.23625000000000002
# Enigma M4 to TypeX :  0.04
# TypeX to Enigma :  0.038181818181818185
# TypeX to Enigma M4 :  0.013636363636363636
# Epoch 1020000 D loss: 1.0759611129760742 G_loss: 3.348113536834717
# Enigma to plain :  0.02625
# Enigma M4 to plain :  0.006666666666666667
# TypeX to plain :  0.016
# plain to Enigma :  0.048
# plain to Enigma M4 :  0.022
# plain to Enigma :  0.03899999999999999
# Enigma to Enigma M4 :  0.01625
# Enigma to TypeX :  0.04125
# Enigma M4 to Enigma :  0.23444444444444443
# Enigma M4 to TypeX :  0.02666666666666667
# TypeX to Enigma :  0.034
# TypeX to Enigma M4 :  0.016
# Epoch 1030000 D loss: 2.4845995903015137 G_loss: 5.588837623596191
# Enigma to plain :  0.01
# Enigma M4 to plain :  0.006666666666666667
# TypeX to plain :  0.013333333333333334
# plain to Enigma :  0.026666666666666665
# plain to Enigma M4 :  0.008888888888888887
# plain to Enigma :  0.03444444444444445
# Enigma to Enigma M4 :  0.008
# Enigma to TypeX :  0.046
# Enigma M4 to Enigma :  0.3677777777777778
# Enigma M4 to TypeX :  0.04666666666666666
# TypeX to Enigma :  0.05666666666666667
# TypeX to Enigma M4 :  0.03444444444444445
# Epoch 1040000 D loss: 1.0640819072723389 G_loss: 2.004385232925415
# Enigma to plain :  0.017777777777777778
# Enigma M4 to plain :  0.008333333333333333
# TypeX to plain :  0.00909090909090909
# plain to Enigma :  0.04666666666666667
# plain to Enigma M4 :  0.015
# plain to Enigma :  0.015000000000000001
# Enigma to Enigma M4 :  0.02111111111111111
# Enigma to TypeX :  0.042222222222222223
# Enigma M4 to Enigma :  0.3316666666666667
# Enigma M4 to TypeX :  0.04
# TypeX to Enigma :  0.03272727272727272
# TypeX to Enigma M4 :  0.011818181818181818
# Epoch 1050000 D loss: 2.295881509780884 G_loss: 3.7286691665649414
# Enigma to plain :  0.011111111111111112
# Enigma M4 to plain :  0.007777777777777778
# TypeX to plain :  0.01
# plain to Enigma :  0.041666666666666664
# plain to Enigma M4 :  0.013333333333333334
# plain to Enigma :  0.03166666666666667
# Enigma to Enigma M4 :  0.025555555555555554
# Enigma to TypeX :  0.05
# Enigma M4 to Enigma :  0.2288888888888889
# Enigma M4 to TypeX :  0.03666666666666667
# TypeX to Enigma :  0.0475
# TypeX to Enigma M4 :  0.0125

# %%
# !python /kaggle/working/UC-GAN-v.2/main.py

# %%
# %cd /kaggle/working/UC-GAN-v.2

# %%
# import torch
# from data_loader import get_loader

# data_loader = data_loader.get_loader(data_loader)
# data_iter = iter(data_loader)
# x_real, label_org = next(data_iter)
# x_real, label_org # will print out x_real, label_org's values
