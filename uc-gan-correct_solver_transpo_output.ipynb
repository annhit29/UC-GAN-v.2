# %%
# !git clone https://github.com/annhit29/UC-GAN-v.2.git
# Out:
# Cloning into 'UC-GAN-v.2'...
# remote: Enumerating objects: 1293, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 1293 (delta 6), reused 10 (delta 4), pack-reused 1280
# Receiving objects: 100% (1293/1293), 14.45 MiB | 26.14 MiB/s, done.
# Resolving deltas: 100% (546/546), done.

# %%
# !pip install catboost

# %%
# !pip install pyenigma

# %%
# %cd /kaggle/working/
# Out:
# /kaggle/working

# %%
# !python /kaggle/working/UC-GAN-v.2/main.py --solver_type transposition
# Out:
# Start training...
# Epoch 0 D loss: 84.01702117919922 G_loss: 4.42435359954834
# Rail-fence to plain :  0.4739999999999999
# Columnar to plain :  0.47000000000000003
# Transpo to plain :  0.48375
# plain to Rail-fence :  0.47833333333333333
# plain to Columnar :  0.48500000000000004
# plain to Transposition :  0.47833333333333333
# Rail-fence to Columnar :  0.4739999999999999
# Rail-fence to Transposition :  0.46799999999999997
# Columnar to Rail-fence :  0.46749999999999997
# Columnar to Transposition :  0.46874999999999994
# Transpo to Rail-fence :  0.4749999999999999
# Transpo to Columnar :  0.48375
# Epoch 10000 D loss: 3.0350136756896973 G_loss: 1.7100253105163574
# Rail-fence to plain :  0.4766666666666666
# Columnar to plain :  0.4633333333333334
# Transpo to plain :  0.47
# plain to Rail-fence :  0.4616666666666667
# plain to Columnar :  0.4616666666666667
# plain to Transposition :  0.4616666666666667
# Rail-fence to Columnar :  0.4766666666666666
# ...

# %%
# !python /kaggle/working/UC-GAN-v.2/main.py

# %%
# %cd /kaggle/working/UC-GAN-v.2

# %%
# import torch
# from data_loader import get_loader

# data_loader = data_loader.get_loader(data_loader)
# data_iter = iter(data_loader)
# x_real, label_org = next(data_iter)
# x_real, label_org # will print out x_real, label_org's values
